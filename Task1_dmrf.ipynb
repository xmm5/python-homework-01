# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ds-reboot/python-first-part/blob/main/notebooks/hometasks/Task1_dmrf.ipynb)

# %% [markdown]
# # Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# # Задание *
# * Написать скрипт, который скачивает фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
import requests
import os
import pickle
import math
import hashlib
import json
import pandas as pd
import sqlite3

from tqdm.auto import tqdm
from collections import defaultdict

# %% [markdown]
# ## Список объектов
#
# > Загружаемые об объектах данные кэшируем на диске в папку `./data`, чтобы постоянно не загружать данные с сайта.

# %%
BASE_DIR = "data"

# Для хранения временных файлов.
os.makedirs("data/objects", exist_ok=True)

# %% [markdown]
# ### Скачать ID всех объектов

# %%
object_ids = set()  # Только уникальные ID объектов.

url = 'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object'
url_params = {
    "offset": 0,
    "limit": 0,
    "sortField": "devId.devShortCleanNm",
    "sortType": "asc",
    "objStatus": 0,
}

# Файл содержащий ID объектов.
object_ids_file_path = f"{BASE_DIR}/object_ids.pkl"

if not os.path.isfile(object_ids_file_path):
    # Прочитать общее количество объектов.
    url_params["offset"] = 0
    url_params["limit"] = 1
    res = requests.get(url, params=url_params)
    objects_data = res.json()
    objects_total = objects_data.get("data").get("total")
    print("total:", objects_total)
  
    # Чтение всех объектов и сохранение всех ID объектов в файл,
    # чтобы повторно не вычитывать данные из сети.
    objects_offset = 0
    objects_limit = 100
    
    # Количество URL содержащих objects_limit объектов.
    iterations_count = math.ceil(objects_total/objects_limit)

    for i in tqdm(range(iterations_count)):
        # Скачать данные.
        url_params["offset"] = objects_offset
        url_params["limit"] = objects_limit
        res = requests.get(url, params=url_params)

        if 200 != res.status_code:
            break

        objects_data = res.json()
        objects_total = objects_data.get("data").get("total")
        objects_list = objects_data.get("data").get("list")
        object_ids.update([x.get("objId") for x in objects_list])

        objects_offset += objects_limit

    # Сохранить ID всех объектов в файл.
    with open(object_ids_file_path, "wb") as f:
        pickle.dump(object_ids, f)
else:
    # Файл содержащий ID всех объектов уже есть.
    with open(object_ids_file_path, "rb") as f:
        object_ids = pickle.load(f)

print("total IDs", len(object_ids))
# Out:
# total IDs 10777

# %% [markdown]
# ## Скачать данные по объектам

# %%
objects = []  # Данные объектов.

for object_id in tqdm(object_ids):
    object_id_hash = hashlib.md5(str(object_id).encode("utf-8")).hexdigest()
    object_file_path = f"{BASE_DIR}/objects/{object_id_hash[:2]}/{object_id}.pkl"

    if not os.path.isfile(object_file_path):
        # Скачать данные объекта.
        url = f"https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{object_id}"
        res = requests.get(url)

        if 200 != res.status_code:
            continue

        object_data = res.json()
        objects.append(object_data)

        # Сохранить объект в файл.
        os.makedirs(os.path.dirname(object_file_path), exist_ok=True)

        with open(object_file_path, "wb") as f:
            pickle.dump(object_data, f)
    else:
        # Данные объектов уже есть.
        with open(object_file_path, "rb") as f:
            object_data = pickle.load(f)
            objects.append(object_data)
            
print("total objects:", len(objects))
# Out:
#   0%|          | 0/10777 [00:00<?, ?it/s]
# total objects: 10777

# %% [markdown]
# ## Cохранение информации о всех строящихся объектах

# %%
# Сохранить в pandas DataFrame из JSON'а как есть.
df = pd.json_normalize(objects)
df
# Out:
#       errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0           0    32787        43579     181636                  6946
# 1           0    32793        43585     162963                  6434
# 2           0    32849        43641     167016                  1577
# 3           0    32892        43687     117906                  2551
# 4           0    32893        43688     117906                  2551
# ...       ...      ...          ...        ...                   ...
# 10772       0    32607        43387     166974                  1195
# 10773       0    32608        43388     166974                  1195
# 10774       0    32611        43391     169884                  7951
# 10775       0    32618        43405     152681                  2224
# 10776       0    32736        43526     173973                  4343
#
#       data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                                ТКС                       ТКС
# 1                       СЗ ДЖЕВОССЕТ              СЗ ДЖЕВОССЕТ
# 2                   СЗ КАПИТАЛ ГРУПП          СЗ КАПИТАЛ ГРУПП
# 3                            СЗ МАГИ                   СЗ МАГИ
# 4                            СЗ МАГИ                   СЗ МАГИ
# ...                              ...                       ...
# 10772                     ИНВЕСТЛЭНД                ИНВЕСТЛЭНД
# 10773                     ИНВЕСТЛЭНД                ИНВЕСТЛЭНД
# 10774                  ДИПЛОМАТ ПЛЮС             ДИПЛОМАТ ПЛЮС
# 10775                       КРЕПОСТЬ                  КРЕПОСТЬ
# 10776                      КМ-ИНВЕСТ                 КМ-ИНВЕСТ
#
#                      data.developer.devFullCleanNm  \
# 0                                      ТАТКАМСТРОЙ
# 1          СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ДЖЕВОССЕТ
# 2      СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК КАПИТАЛ ГРУПП
# 3                СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИКМАГИ
# 4                СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИКМАГИ
# ...                                            ...
# 10772                                   ИНВЕСТЛЭНД
# 10773                                   ИНВЕСТЛЭНД
# 10774                                ДИПЛОМАТ ПЛЮС
# 10775                                     КРЕПОСТЬ
# 10776                                    КМ-ИНВЕСТ
#
#        data.developer.problObjCnt  data.developer.buildObjCnt  ...  \
# 0                               0                           2  ...
# 1                               0                           1  ...
# 2                               0                           1  ...
# 3                               0                          12  ...
# 4                               0                          12  ...
# ...                           ...                         ...  ...
# 10772                           0                          13  ...
# 10773                           0                          13  ...
# 10774                           0                           1  ...
# 10775                           0                           1  ...
# 10776                           0                           1  ...
#
#        data.metro.colors data.airQualityIndexValue data.transportDistIndex  \
# 0                    NaN                       NaN                     NaN
# 1              [#0072BA]                       7.0                     NaN
# 2                    NaN                       NaN                     NaN
# 3                    NaN                       6.0                     NaN
# 4                    NaN                       6.0                     NaN
# ...                  ...                       ...                     ...
# 10772                NaN                       6.0                     NaN
# 10773                NaN                       6.0                     NaN
# 10774                NaN                       NaN                     NaN
# 10775                NaN                       NaN                     NaN
# 10776                NaN                       NaN                     NaN
#
#       data.transportDistIndexValue data.greenAreaIndexValue  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
# ...                            ...                      ...
# 10772                          NaN                      NaN
# 10773                          NaN                      NaN
# 10774                          NaN                      NaN
# 10775                          NaN                      NaN
# 10776                          NaN                      NaN
#
#       data.complexShortNm data.developer.bankruptStage.bankruptStageCd  \
# 0                     NaN                                          NaN
# 1                     NaN                                          NaN
# 2                     NaN                                          NaN
# 3                     NaN                                          NaN
# 4                     NaN                                          NaN
# ...                   ...                                          ...
# 10772                 NaN                                          NaN
# 10773                 NaN                                          NaN
# 10774                 NaN                                          NaN
# 10775                 NaN                                          NaN
# 10776                 NaN                                          NaN
#
#       data.developer.bankruptStage.bankruptStageDesc  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 10772                                            NaN
# 10773                                            NaN
# 10774                                            NaN
# 10775                                            NaN
# 10776                                            NaN
#
#       data.developer.bankruptStage.bankruptLawUrl  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 10772                                         NaN
# 10773                                         NaN
# 10774                                         NaN
# 10775                                         NaN
# 10776                                         NaN
#
#       data.developer.orgBankruptMsgDttm
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 10772                               NaN
# 10773                               NaN
# 10774                               NaN
# 10775                               NaN
# 10776                               NaN
#
# [10777 rows x 111 columns]

# %% [markdown]
# ### Сохранить в pandas DataFrame из JSON'а выбрав основные поля данных

# %%
# Поиск элемента в JSON'е.
def json_search(json_data, key, default=None):
    try:
        for nested_key in key.split("."): 
            json_data = json_data.get(nested_key)
        return json_data
    except AttributeError:
        return default

# Поиск object в JSON'е по его ID.
def find_object_by_id(objects, id):
    for i, object in enumerate(objects):
        if id == json_search(object, "data.id"):
            return i
    raise LookupError(f"Object with ID={id} not found")

# %%
# Подготовка данных для сохранения в DataFrame.
tab_dict = defaultdict(list)

# Для отладки
# offset = find_object_by_id(objects, 46687)
# objects = objects[offset:offset+10]

for object in tqdm(objects):
    tab_dict["id"].append(json_search(object, "data.id"))
    
    tab_dict["Застройщик"].append(" ".join([
        json_search(object, "data.developer.orgForm.shortForm"),
        json_search(object, "data.developer.devShortNm")
    ]))
    tab_dict["Группа компаний"].append(json_search(object, "data.developer.developerGroupName"))
    tab_dict["ЖК"].append(json_search(object, "data.nameObj"))
   
    tab_dict["Ввод в эксплуатацию"].append(json_search(object, "data.objReady100PercDt"))
    tab_dict["Выдача ключей"].append(json_search(object, "data.objTransferPlanDt"))
    tab_dict["Средняя цена за 1 м2"].append(json_search(object, "data.objPriceAvg"))
    tab_dict["Распроданность квартир"].append(json_search(object, "data.soldOutPerc"))
    
    tab_dict["Класс энергоэффективности здания"].append(json_search(object, "data.objEnergyEffShortDesc"))
    tab_dict["Генподрядчики"].append(json_search(object, "data.generalContractorNm"))
    
    # Основные характеристики
    tab_dict["Класс недвижимости"].append(json_search(object, "data.objLkClassDesc"))
    tab_dict["Материал стен"].append(json_search(object, "data.wallMaterialShortDesc"))
    tab_dict["Тип отделки"].append(json_search(object, "data.objLkFinishTypeDesc"))
    tab_dict["Свободная планировка"].append(json_search(object, "data.objLkFreePlanDesc"))
    tab_dict["Количество этажей"].append(json_search(object, "data.objFloorCnt"))
    tab_dict["Количество квартир"].append(json_search(object, "data.objElemLivingCnt"))
    tab_dict["Жилая площадь, м2"].append(json_search(object, "data.objSquareLiving"))
    tab_dict["Высота потолков, м"].append(json_search(object, "data.objLivCeilingHeight"))
    
    # Благоустройство двора
    tab_dict["Велосипедные дорожки"].append(json_search(object, "data.objInfrstrBicycleLaneFlg"))
    tab_dict["Количество детских площадок"].append(json_search(object, "data.objInfrstrPlaygrndCnt"))
    tab_dict["Количество спортивных площадок"].append(json_search(object, "data.objInfrstrSportGroundCnt"))
    tab_dict["Количество площадок для сбора мусора"].append(json_search(object, "data.objInfrstrTrashAreaCnt"))
    
    # Парковочное пространство
    tab_dict["Количество мест в паркинге"].append(json_search(object, "data.objElemParkingCnt"))
    tab_dict["Гостевые места на придомовой территории"].append(json_search(object, "data.objInfrstrObjPrkngCnt"))
    tab_dict["Гостевые места вне придомовой территории"].append(json_search(object, "data.objInfrstrNotObjPrkngCnt"))
    
    # Безбарьерная среда
    tab_dict["Наличие пандуса"].append(json_search(object, "data.objInfrstrRampFlg"))
    tab_dict["Наличие понижающих площадок"].append(json_search(object, "data.objInfrstrCurbLoweringFlg"))
    tab_dict["Количество инвалидных подъемников"].append(json_search(object, "data.objElevatorWheelchairCnt"))
    
    # Наличие лифтов в доме
    tab_dict["Количество подъездов"].append(json_search(object, "data.quartography.objLivElemEntrCnt"))
    tab_dict["Количество пассажирских лифтов"].append(json_search(object, "data.objElevatorPassengerCnt"))
    tab_dict["Количество грузовых и грузопассажирских лифтов"].append(json_search(object, "data.objElevatorCargoPassengerCnt"))
# Out:
#   0%|          | 0/10777 [00:00<?, ?it/s]

# %%
# Cохранить в DataFrame.
df = pd.DataFrame(tab_dict)
df
# Out:
#           id            Застройщик           Группа компаний  \
# 0      32787               ООО ТКС               ТАТКАМСТРОЙ
# 1      32793      ООО СЗ ДЖЕВОССЕТ  ПроГород (группа ВЭБ.РФ)
# 2      32849  ООО СЗ КАПИТАЛ ГРУПП  Центр Строительных Услуг
# 3      32892           ООО СЗ МАГИ                      None
# 4      32893           ООО СЗ МАГИ                      None
# ...      ...                   ...                       ...
# 10772  32607        ООО ИНВЕСТЛЭНД           Villagio Estate
# 10773  32608        ООО ИНВЕСТЛЭНД           Villagio Estate
# 10774  32611     ООО ДИПЛОМАТ ПЛЮС              ВнешОптоТорг
# 10775  32618          ООО КРЕПОСТЬ        Регион Девелопмент
# 10776  32736         ООО КМ-ИНВЕСТ                 КМ-Инвест
#
#                                                       ЖК Ввод в эксплуатацию  \
# 0                                       ЖК "Современный"          2022-12-31
# 1                                    Микрогород "В лесу"          2023-03-31
# 2                          Микрорайон "Тихий Берег", 004          2022-12-31
# 3                                     ЖК "СКАЗКА" дом 64          2022-12-31
# 4                                     ЖК "СКАЗКА" дом 65          2022-12-31
# ...                                                  ...                 ...
# 10772           ЖК Футуро Парк (Futuro Park), Корпус №58          2023-12-31
# 10773           ЖК Футуро Парк (Futuro Park), Корпус №59          2023-12-31
# 10774                                    ЖК "Южное море"          2031-03-31
# 10775  Жилой комплекс "пер.Светлогорский II очередь о...          2025-09-30
# 10776                                         Курья Park          2023-06-30
#
#           Выдача ключей  Средняя цена за 1 м2  Распроданность квартир  \
# 0      28-02-2023 12:00               61816.0                1.000000
# 1      31-08-2023 12:00              151912.0                0.863037
# 2      29-12-2023 12:00               51105.0                0.953005
# 3      28-02-2023 12:00              160261.0                0.470130
# 4      28-02-2023 12:00              148909.0                0.648701
# ...                 ...                   ...                     ...
# 10772  29-02-2024 12:00                   NaN                     NaN
# 10773  29-02-2024 12:00                   NaN                     NaN
# 10774  17-09-2031 12:00               94409.0                1.000000
# 10775  31-07-2025 12:00               83647.0                0.146932
# 10776  30-11-2023 12:00               62509.0                0.247276
#
#       Класс энергоэффективности здания  \
# 0                                    A
# 1                                    B
# 2                                    D
# 3                                    A
# 4                                    A
# ...                                ...
# 10772                                B
# 10773                                B
# 10774                                B
# 10775                               A+
# 10776                                A
#
#                                            Генподрядчики  ...  \
# 0                         ООО "Билант" (ИНН: 1651000203)  ...
# 1                ООО "Компания Б.В.С." (ИНН: 7703543324)  ...
# 2                 ООО "Кохмаситистрой" (ИНН: 3702149712)  ...
# 3                      ООО Перспектива (ИНН: 7728883629)  ...
# 4                      ООО Перспектива (ИНН: 7728883629)  ...
# ...                                                  ...  ...
# 10772                    ООО Проектион (ИНН: 5024207331)  ...
# 10773                    ООО Проектион (ИНН: 5024207331)  ...
# 10774                           ООО КР (ИНН: 2367000898)  ...
# 10775                                               None  ...
# 10776  ООО "Управляющая компания "ИнтерСтройИнвест" (...  ...
#
#       Количество площадок для сбора мусора Количество мест в паркинге  \
# 0                                      1.0                          0
# 1                                      1.0                        264
# 2                                      1.0                          0
# 3                                      1.0                          0
# 4                                      1.0                          0
# ...                                    ...                        ...
# 10772                                  2.0                          0
# 10773                                  2.0                          0
# 10774                                  1.0                          0
# 10775                                  0.0                          0
# 10776                                  1.0                         15
#
#       Гостевые места на придомовой территории  \
# 0                                        89.0
# 1                                       139.0
# 2                                        10.0
# 3                                        15.0
# 4                                        15.0
# ...                                       ...
# 10772                                    14.0
# 10773                                    14.0
# 10774                                     0.0
# 10775                                    52.0
# 10776                                    40.0
#
#       Гостевые места вне придомовой территории  Наличие пандуса  \
# 0                                        282.0                1
# 1                                          0.0                1
# 2                                         10.0                1
# 3                                          0.0                0
# 4                                          0.0                0
# ...                                        ...              ...
# 10772                                     30.0                0
# 10773                                     30.0                0
# 10774                                      0.0                1
# 10775                                      0.0                0
# 10776                                     56.0                1
#
#        Наличие понижающих площадок  Количество инвалидных подъемников  \
# 0                                1                                0.0
# 1                                1                                0.0
# 2                                1                                8.0
# 3                                1                                0.0
# 4                                1                                0.0
# ...                            ...                                ...
# 10772                            1                                0.0
# 10773                            1                                0.0
# 10774                            1                                0.0
# 10775                            1                               11.0
# 10776                            1                                0.0
#
#       Количество подъездов  Количество пассажирских лифтов  \
# 0                      1.0                             1.0
# 1                      8.0                            14.0
# 2                      5.0                             3.0
# 3                      2.0                             2.0
# 4                      2.0                             2.0
# ...                    ...                             ...
# 10772                  2.0                             0.0
# 10773                  2.0                             0.0
# 10774                  1.0                             2.0
# 10775                  3.0                             3.0
# 10776                  1.0                             3.0
#
#        Количество грузовых и грузопассажирских лифтов
# 0                                                   1
# 1                                                  22
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 10772                                               0
# 10773                                               0
# 10774                                               2
# 10775                                               3
# 10776                                               5
#
# [10777 rows x 31 columns]

# %%
# Cохрание DataFrame в Excel.
xlsx_file_path = f"{BASE_DIR}/nashdom.xlsx"

df.to_excel(xlsx_file_path, index=False)

# %%
# Загрузка DataFrame из Excel.
df_from_excel = pd.read_excel(xlsx_file_path, index_col=0)
df_from_excel
# Out:
#                  Застройщик           Группа компаний  \
# id
# 32787               ООО ТКС               ТАТКАМСТРОЙ
# 32793      ООО СЗ ДЖЕВОССЕТ  ПроГород (группа ВЭБ.РФ)
# 32849  ООО СЗ КАПИТАЛ ГРУПП  Центр Строительных Услуг
# 32892           ООО СЗ МАГИ                       NaN
# 32893           ООО СЗ МАГИ                       NaN
# ...                     ...                       ...
# 32607        ООО ИНВЕСТЛЭНД           Villagio Estate
# 32608        ООО ИНВЕСТЛЭНД           Villagio Estate
# 32611     ООО ДИПЛОМАТ ПЛЮС              ВнешОптоТорг
# 32618          ООО КРЕПОСТЬ        Регион Девелопмент
# 32736         ООО КМ-ИНВЕСТ                 КМ-Инвест
#
#                                                       ЖК Ввод в эксплуатацию  \
# id
# 32787                                   ЖК "Современный"          2022-12-31
# 32793                                Микрогород "В лесу"          2023-03-31
# 32849                      Микрорайон "Тихий Берег", 004          2022-12-31
# 32892                                 ЖК "СКАЗКА" дом 64          2022-12-31
# 32893                                 ЖК "СКАЗКА" дом 65          2022-12-31
# ...                                                  ...                 ...
# 32607           ЖК Футуро Парк (Futuro Park), Корпус №58          2023-12-31
# 32608           ЖК Футуро Парк (Futuro Park), Корпус №59          2023-12-31
# 32611                                    ЖК "Южное море"          2031-03-31
# 32618  Жилой комплекс "пер.Светлогорский II очередь о...          2025-09-30
# 32736                                         Курья Park          2023-06-30
#
#           Выдача ключей  Средняя цена за 1 м2  Распроданность квартир  \
# id
# 32787  28-02-2023 12:00               61816.0                1.000000
# 32793  31-08-2023 12:00              151912.0                0.863037
# 32849  29-12-2023 12:00               51105.0                0.953005
# 32892  28-02-2023 12:00              160261.0                0.470130
# 32893  28-02-2023 12:00              148909.0                0.648701
# ...                 ...                   ...                     ...
# 32607  29-02-2024 12:00                   NaN                     NaN
# 32608  29-02-2024 12:00                   NaN                     NaN
# 32611  17-09-2031 12:00               94409.0                1.000000
# 32618  31-07-2025 12:00               83647.0                0.146932
# 32736  30-11-2023 12:00               62509.0                0.247276
#
#       Класс энергоэффективности здания  \
# id
# 32787                                A
# 32793                                B
# 32849                                D
# 32892                                A
# 32893                                A
# ...                                ...
# 32607                                B
# 32608                                B
# 32611                                B
# 32618                               A+
# 32736                                A
#
#                                            Генподрядчики Класс недвижимости  \
# id
# 32787                     ООО "Билант" (ИНН: 1651000203)            Комфорт
# 32793            ООО "Компания Б.В.С." (ИНН: 7703543324)            Комфорт
# 32849             ООО "Кохмаситистрой" (ИНН: 3702149712)            Комфорт
# 32892                  ООО Перспектива (ИНН: 7728883629)             Бизнес
# 32893                  ООО Перспектива (ИНН: 7728883629)             Бизнес
# ...                                                  ...                ...
# 32607                    ООО Проектион (ИНН: 5024207331)             Бизнес
# 32608                    ООО Проектион (ИНН: 5024207331)             Бизнес
# 32611                           ООО КР (ИНН: 2367000898)             Бизнес
# 32618                                                NaN            Типовой
# 32736  ООО "Управляющая компания "ИнтерСтройИнвест" (...            Комфорт
#
#        ... Количество площадок для сбора мусора Количество мест в паркинге  \
# id     ...
# 32787  ...                                  1.0                          0
# 32793  ...                                  1.0                        264
# 32849  ...                                  1.0                          0
# 32892  ...                                  1.0                          0
# 32893  ...                                  1.0                          0
# ...    ...                                  ...                        ...
# 32607  ...                                  2.0                          0
# 32608  ...                                  2.0                          0
# 32611  ...                                  1.0                          0
# 32618  ...                                  0.0                          0
# 32736  ...                                  1.0                         15
#
#       Гостевые места на придомовой территории  \
# id
# 32787                                    89.0
# 32793                                   139.0
# 32849                                    10.0
# 32892                                    15.0
# 32893                                    15.0
# ...                                       ...
# 32607                                    14.0
# 32608                                    14.0
# 32611                                     0.0
# 32618                                    52.0
# 32736                                    40.0
#
#        Гостевые места вне придомовой территории  Наличие пандуса  \
# id
# 32787                                     282.0                1
# 32793                                       0.0                1
# 32849                                      10.0                1
# 32892                                       0.0                0
# 32893                                       0.0                0
# ...                                         ...              ...
# 32607                                      30.0                0
# 32608                                      30.0                0
# 32611                                       0.0                1
# 32618                                       0.0                0
# 32736                                      56.0                1
#
#        Наличие понижающих площадок Количество инвалидных подъемников  \
# id
# 32787                            1                               0.0
# 32793                            1                               0.0
# 32849                            1                               8.0
# 32892                            1                               0.0
# 32893                            1                               0.0
# ...                            ...                               ...
# 32607                            1                               0.0
# 32608                            1                               0.0
# 32611                            1                               0.0
# 32618                            1                              11.0
# 32736                            1                               0.0
#
#        Количество подъездов  Количество пассажирских лифтов  \
# id
# 32787                   1.0                             1.0
# 32793                   8.0                            14.0
# 32849                   5.0                             3.0
# 32892                   2.0                             2.0
# 32893                   2.0                             2.0
# ...                     ...                             ...
# 32607                   2.0                             0.0
# 32608                   2.0                             0.0
# 32611                   1.0                             2.0
# 32618                   3.0                             3.0
# 32736                   1.0                             3.0
#
#        Количество грузовых и грузопассажирских лифтов
# id
# 32787                                               1
# 32793                                              22
# 32849                                               0
# 32892                                               0
# 32893                                               0
# ...                                               ...
# 32607                                               0
# 32608                                               0
# 32611                                               2
# 32618                                               3
# 32736                                               5
#
# [10777 rows x 30 columns]

# %%
# Сохранение DataFrame в pickle.
pkl_file_path = f"{BASE_DIR}/nashdom.pkl"

df.to_pickle(pkl_file_path)

# %%
# Загрузка DataFrame из pickle.
df_from_pickle = pd.read_pickle(pkl_file_path)
df_from_pickle
# Out:
#           id            Застройщик           Группа компаний  \
# 0      32787               ООО ТКС               ТАТКАМСТРОЙ
# 1      32793      ООО СЗ ДЖЕВОССЕТ  ПроГород (группа ВЭБ.РФ)
# 2      32849  ООО СЗ КАПИТАЛ ГРУПП  Центр Строительных Услуг
# 3      32892           ООО СЗ МАГИ                      None
# 4      32893           ООО СЗ МАГИ                      None
# ...      ...                   ...                       ...
# 10772  32607        ООО ИНВЕСТЛЭНД           Villagio Estate
# 10773  32608        ООО ИНВЕСТЛЭНД           Villagio Estate
# 10774  32611     ООО ДИПЛОМАТ ПЛЮС              ВнешОптоТорг
# 10775  32618          ООО КРЕПОСТЬ        Регион Девелопмент
# 10776  32736         ООО КМ-ИНВЕСТ                 КМ-Инвест
#
#                                                       ЖК Ввод в эксплуатацию  \
# 0                                       ЖК "Современный"          2022-12-31
# 1                                    Микрогород "В лесу"          2023-03-31
# 2                          Микрорайон "Тихий Берег", 004          2022-12-31
# 3                                     ЖК "СКАЗКА" дом 64          2022-12-31
# 4                                     ЖК "СКАЗКА" дом 65          2022-12-31
# ...                                                  ...                 ...
# 10772           ЖК Футуро Парк (Futuro Park), Корпус №58          2023-12-31
# 10773           ЖК Футуро Парк (Futuro Park), Корпус №59          2023-12-31
# 10774                                    ЖК "Южное море"          2031-03-31
# 10775  Жилой комплекс "пер.Светлогорский II очередь о...          2025-09-30
# 10776                                         Курья Park          2023-06-30
#
#           Выдача ключей  Средняя цена за 1 м2  Распроданность квартир  \
# 0      28-02-2023 12:00               61816.0                1.000000
# 1      31-08-2023 12:00              151912.0                0.863037
# 2      29-12-2023 12:00               51105.0                0.953005
# 3      28-02-2023 12:00              160261.0                0.470130
# 4      28-02-2023 12:00              148909.0                0.648701
# ...                 ...                   ...                     ...
# 10772  29-02-2024 12:00                   NaN                     NaN
# 10773  29-02-2024 12:00                   NaN                     NaN
# 10774  17-09-2031 12:00               94409.0                1.000000
# 10775  31-07-2025 12:00               83647.0                0.146932
# 10776  30-11-2023 12:00               62509.0                0.247276
#
#       Класс энергоэффективности здания  \
# 0                                    A
# 1                                    B
# 2                                    D
# 3                                    A
# 4                                    A
# ...                                ...
# 10772                                B
# 10773                                B
# 10774                                B
# 10775                               A+
# 10776                                A
#
#                                            Генподрядчики  ...  \
# 0                         ООО "Билант" (ИНН: 1651000203)  ...
# 1                ООО "Компания Б.В.С." (ИНН: 7703543324)  ...
# 2                 ООО "Кохмаситистрой" (ИНН: 3702149712)  ...
# 3                      ООО Перспектива (ИНН: 7728883629)  ...
# 4                      ООО Перспектива (ИНН: 7728883629)  ...
# ...                                                  ...  ...
# 10772                    ООО Проектион (ИНН: 5024207331)  ...
# 10773                    ООО Проектион (ИНН: 5024207331)  ...
# 10774                           ООО КР (ИНН: 2367000898)  ...
# 10775                                               None  ...
# 10776  ООО "Управляющая компания "ИнтерСтройИнвест" (...  ...
#
#       Количество площадок для сбора мусора Количество мест в паркинге  \
# 0                                      1.0                          0
# 1                                      1.0                        264
# 2                                      1.0                          0
# 3                                      1.0                          0
# 4                                      1.0                          0
# ...                                    ...                        ...
# 10772                                  2.0                          0
# 10773                                  2.0                          0
# 10774                                  1.0                          0
# 10775                                  0.0                          0
# 10776                                  1.0                         15
#
#       Гостевые места на придомовой территории  \
# 0                                        89.0
# 1                                       139.0
# 2                                        10.0
# 3                                        15.0
# 4                                        15.0
# ...                                       ...
# 10772                                    14.0
# 10773                                    14.0
# 10774                                     0.0
# 10775                                    52.0
# 10776                                    40.0
#
#       Гостевые места вне придомовой территории  Наличие пандуса  \
# 0                                        282.0                1
# 1                                          0.0                1
# 2                                         10.0                1
# 3                                          0.0                0
# 4                                          0.0                0
# ...                                        ...              ...
# 10772                                     30.0                0
# 10773                                     30.0                0
# 10774                                      0.0                1
# 10775                                      0.0                0
# 10776                                     56.0                1
#
#        Наличие понижающих площадок  Количество инвалидных подъемников  \
# 0                                1                                0.0
# 1                                1                                0.0
# 2                                1                                8.0
# 3                                1                                0.0
# 4                                1                                0.0
# ...                            ...                                ...
# 10772                            1                                0.0
# 10773                            1                                0.0
# 10774                            1                                0.0
# 10775                            1                               11.0
# 10776                            1                                0.0
#
#       Количество подъездов  Количество пассажирских лифтов  \
# 0                      1.0                             1.0
# 1                      8.0                            14.0
# 2                      5.0                             3.0
# 3                      2.0                             2.0
# 4                      2.0                             2.0
# ...                    ...                             ...
# 10772                  2.0                             0.0
# 10773                  2.0                             0.0
# 10774                  1.0                             2.0
# 10775                  3.0                             3.0
# 10776                  1.0                             3.0
#
#        Количество грузовых и грузопассажирских лифтов
# 0                                                   1
# 1                                                  22
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 10772                                               0
# 10773                                               0
# 10774                                               2
# 10775                                               3
# 10776                                               5
#
# [10777 rows x 31 columns]

# %%
# Сохранение DataFrame в БД sqlite3.
db_path = f"{BASE_DIR}/nashdom.sqlite3"
conn = sqlite3.connect(db_path)
df.to_sql("nashdom", conn, if_exists="replace", index = False)
conn.commit()
conn.close()

# %%
# Загрузка DataFrame из БД sqlite3.
conn = sqlite3.connect(db_path)
df_sql = pd.read_sql('SELECT * FROM "nashdom" ORDER BY "Застройщик" LIMIT 5', conn)
conn.close()
df_sql
# Out:
#       id     Застройщик         Группа компаний    ЖК Ввод в эксплуатацию  \
# 0  13383  АО 2МЕН ГРУПП  2МЕН ГРУПП ДЕВЕЛОПМЕНТ  None          2022-12-31
# 1  13391  АО 2МЕН ГРУПП  2МЕН ГРУПП ДЕВЕЛОПМЕНТ  None          2022-12-31
# 2  13397  АО 2МЕН ГРУПП  2МЕН ГРУПП ДЕВЕЛОПМЕНТ  None          2024-12-31
# 3  13398  АО 2МЕН ГРУПП  2МЕН ГРУПП ДЕВЕЛОПМЕНТ  None          2024-12-31
# 4  13399  АО 2МЕН ГРУПП  2МЕН ГРУПП ДЕВЕЛОПМЕНТ  None          2024-12-31
#
#       Выдача ключей  Средняя цена за 1 м2  Распроданность квартир  \
# 0  28-02-2023 12:00               53109.0                0.406985
# 1  28-02-2023 12:00               55893.0                0.450622
# 2  28-02-2025 12:00               45523.0                0.999984
# 3  28-02-2025 12:00               47886.0                1.000000
# 4  28-02-2025 12:00               50768.0                0.917243
#
#   Класс энергоэффективности здания  \
# 0                                B
# 1                                B
# 2                                B
# 3                                B
# 4                                B
#
#                                   Генподрядчики  ...  \
# 0  ООО Транспромжилстрой-2005 (ИНН: 7204097730)  ...
# 1  ООО Транспромжилстрой-2005 (ИНН: 7204097730)  ...
# 2  ООО Транспромжилстрой-2005 (ИНН: 7204097730)  ...
# 3  ООО Транспромжилстрой-2005 (ИНН: 7204097730)  ...
# 4  ООО Транспромжилстрой-2005 (ИНН: 7204097730)  ...
#
#   Количество площадок для сбора мусора Количество мест в паркинге  \
# 0                                  1.0                         31
# 1                                  1.0                         41
# 2                                  1.0                          0
# 3                                  1.0                          0
# 4                                  1.0                        125
#
#   Гостевые места на придомовой территории  \
# 0                                     0.0
# 1                                     0.0
# 2                                    11.0
# 3                                     4.0
# 4                                     0.0
#
#   Гостевые места вне придомовой территории  Наличие пандуса  \
# 0                                     11.0                1
# 1                                      9.0                1
# 2                                     10.0                1
# 3                                     15.0                1
# 4                                      0.0                1
#
#    Наличие понижающих площадок  Количество инвалидных подъемников  \
# 0                            1                                0.0
# 1                            1                                0.0
# 2                            1                                0.0
# 3                            1                                0.0
# 4                            1                                0.0
#
#   Количество подъездов  Количество пассажирских лифтов  \
# 0                  1.0                             5.0
# 1                  2.0                             2.0
# 2                  4.0                             5.0
# 3                  3.0                             3.0
# 4                  NaN                             8.0
#
#    Количество грузовых и грузопассажирских лифтов
# 0                                               7
# 1                                               6
# 2                                               9
# 3                                               6
# 4                                              15
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Cкачать фотографии для всех строящихся объектов

# %%
def download_photos(objects):
    for object in tqdm(objects):
        object_id = json_search(object, "data.id")
        photo_render_dto = json_search(object, "data.photoRenderDTO")

        for photo in photo_render_dto:
            photo_url = photo.get("objRenderPhotoUrl")
            photo_name = photo.get("objRenderPhotoNm")
            object_ready_desc = photo.get("objReadyDesc").lower()  # Статус объекта.
            
            if object_ready_desc == "строится":
                object_file_path = f"{BASE_DIR}/images/{object_id}/{photo_name}"

                if not os.path.isfile(object_file_path):
                    res = requests.get(photo_url)

                    if 200 != res.status_code:
                        continue

                    os.makedirs(os.path.dirname(object_file_path), exist_ok=True)

                    with open(object_file_path, "wb") as f:
                        f.write(res.content)

# %%
# Остановил загрузку (очень много файлов).
download_photos(objects)
# Out:
#   0%|          | 0/10777 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4551/565675948.py in <module>
#       1 # Остановил загрузку (очень много файлов).
# ----> 2 download_photos(objects)
#
# /tmp/ipykernel_4551/2424194752.py in download_photos(objects)
#      13
#      14                 if not os.path.isfile(object_file_path):
# ---> 15                     res = requests.get(photo_url)
#      16
#      17                     if 200 != res.status_code:
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     412             context.load_default_certs()
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#     416             keyfile=self.key_file,
#
# ~/program-files/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:
